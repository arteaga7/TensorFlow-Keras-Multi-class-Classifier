# %% [markdown]
# # Deep Learning (TensorFlow, Keras) with ResNet50: Image Multi-class Classifier (Part 2)
# In this project, a model is trained to perform multi-class classification for apple, banana and orange pictures. The pretrained model ResNet50 is used. This document is the second part of the whole training process.

# %% [markdown]
# ## Iteration 2: Model retraining, learning_rate=1e-5, data augmentation and fine-tuning (last 10 layers)

# %%
# (height, width, channels)
input_shape = (224, 224, 3)
batch_size = 12
learning_rate = 1e-5
path_dataset = '../fruits_dataset'
folder_apple = 'apple'
folder_banana = 'banana'
folder_orange = 'orange'
folder_models = '../models'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
# Out:
# 2025-10-22 22:13:58.243714: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-22 22:14:02.551024: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-22 22:14:02.558725: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-22 22:14:10.008312: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Data augmentation

# %%
def load_data(path, input_shape=input_shape, batch_size=batch_size, seed=123, validation_split=0.2):
    """Function to create 2 ImageDataGenerators to split dataset into train and validation datasets.
    Data augmentation is not implemented for the validation dataset."""
    height, width = input_shape[:2]
    datagen = ImageDataGenerator(rescale=1.0/255, zoom_range=0.1,
        horizontal_flip=True, vertical_flip=True,
        height_shift_range=0.1, width_shift_range=0.1,
        brightness_range=(0.8, 1.1), rotation_range=60,
        validation_split=validation_split
    )
    train_data = datagen.flow_from_directory(path,
        target_size=(height, width), batch_size=batch_size,
        class_mode='sparse', subset='training', seed=seed
    )
    val_datagen = ImageDataGenerator(rescale=1.0/255,
        validation_split=validation_split
    )
    val_data = val_datagen.flow_from_directory(path,
        target_size=(height, width), batch_size=batch_size,
        class_mode='sparse', subset='validation', seed=seed
    )
    return train_data, val_data

# Split training and validation datasets
train, val = load_data(path_dataset)

print(f"Classes found: {train.class_indices}")
print(f"Training images: {train.samples}")
print(f"Validation images: {val.samples}")
# Out:
# Found 2070 images belonging to 3 classes.
# Found 516 images belonging to 3 classes.
# Classes found: {'apple': 0, 'banana': 1, 'orange': 2}
# Training images: 2070
# Validation images: 516

# %%
# Obtain images and target
images, labels = next(train)

# Show 8 training images (batch_size=8)
figure, axes = plt.subplots(nrows=2,ncols=4, figsize=(8, 6))
for item in zip(axes.ravel(), images, labels):
    axes, image, target = item
    axes.imshow(image)
    axes.set_title(f'Target: {target:0.0f}')
    axes.set_xticks([])
    axes.set_yticks([])
plt.tight_layout()
plt.show()

# Image dimensions
print(images.shape)
# Out:
# (12, 224, 224, 3)

# %% [markdown]
# ### Model retraining (iteration 2)

# %%
def train_model(model, train_data, val_data, epochs, version_model):
    """Function to train the model and save the best one
    according to the validation accuracy."""
    file_name = os.path.join(folder_models,f'sparse_model_v{version_model}.h5')
    
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=0),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=0),
        ModelCheckpoint(file_name, monitor='val_accuracy', save_best_only=True, verbose=1)
    ]

    history = model.fit(train_data, validation_data=val_data,
              epochs=epochs, callbacks=callbacks, verbose=2)

    return model, history

# Load model v1
model_v2 = load_model(os.path.join(folder_models,'sparse_model_v1.h5'))
model_v2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)               262272
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 23850371 (90.98 MB)
# Trainable params: 262659 (1.00 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
epochs = 30
version_model = 2
print(f"Parameters: batch_size = {batch_size}, learning_rate = {learning_rate}, epochs = {epochs}")
# Out:
# Parameters: batch_size = 12, learning_rate = 1e-05, epochs = 30

# %%
# Last 10 layers
for layer in model_v2.layers[0].layers[-10:]:
    layer.trainable = True

# Recompile
model_v2.compile(optimizer=Adam(learning_rate=learning_rate),
loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print(f"TensorFlow Version: {tf.__version__}")

# Ensure GPU is available
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0],True)
    print("GPU is available and memory growth is enabled.")
else:
    print("GPU not available, training will be on CPU.")
# Out:
# TensorFlow Version: 2.13.1
# GPU not available, training will be on CPU.

# %%
# Retrain the model
model_v2, history_stage2 = train_model(model_v2, train, val, epochs=epochs, version_model=version_model)
# Out:
# Epoch 1/30
# 2025-10-22 22:17:19.064136: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 38535168 exceeds 10% of free system memory.
# 2025-10-22 22:17:19.830863: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 38535168 exceeds 10% of free system memory.
# 2025-10-22 22:17:19.874686: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 39923712 exceeds 10% of free system memory.
# 2025-10-22 22:17:19.895116: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 38535168 exceeds 10% of free system memory.
# 2025-10-22 22:17:19.912006: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 38535168 exceeds 10% of free system memory.
# Epoch 1: val_accuracy improved from -inf to 0.37209, saving model to ../models/sparse_model_v2.h5
# /home/ant/TensorFlow-Keras-Multi-class-Classifier/env/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 173/173 - 333s - loss: 0.9356 - accuracy: 0.5696 - val_loss: 1.7498 - val_accuracy: 0.3721 - lr: 1.0000e-05 - 333s/epoch - 2s/step
# Epoch 2/30
#
# Epoch 2: val_accuracy improved from 0.37209 to 0.62209, saving model to ../models/sparse_model_v2.h5
# 173/173 - 376s - loss: 0.7881 - accuracy: 0.6430 - val_loss: 0.8054 - val_accuracy: 0.6221 - lr: 1.0000e-05 - 376s/epoch - 2s/step
# Epoch 3/30
#
# Epoch 3: val_accuracy did not improve from 0.62209
# 173/173 - 371s - loss: 0.7536 - accuracy: 0.6643 - val_loss: 0.8085 - val_accuracy: 0.5930 - lr: 1.0000e-05 - 371s/epoch - 2s/step
# Epoch 4/30
#
# Epoch 4: val_accuracy improved from 0.62209 to 0.63953, saving model to ../models/sparse_model_v2.h5
# 173/173 - 374s - loss: 0.7156 - accuracy: 0.6986 - val_loss: 0.7508 - val_accuracy: 0.6395 - lr: 1.0000e-05 - 374s/epoch - 2s/step
# Epoch 5/30
#
# Epoch 5: val_accuracy improved from 0.63953 to 0.71899, saving model to ../models/sparse_model_v2.h5
# 173/173 - 393s - loss: 0.6556 - accuracy: 0.7251 - val_loss: 0.6182 - val_accuracy: 0.7190 - lr: 1.0000e-05 - 393s/epoch - 2s/step
# Epoch 6/30
#
# Epoch 6: val_accuracy improved from 0.71899 to 0.75194, saving model to ../models/sparse_model_v2.h5
# 173/173 - 309s - loss: 0.6552 - accuracy: 0.7222 - val_loss: 0.5969 - val_accuracy: 0.7519 - lr: 1.0000e-05 - 309s/epoch - 2s/step
# Epoch 7/30
#
# Epoch 7: val_accuracy improved from 0.75194 to 0.75775, saving model to ../models/sparse_model_v2.h5
# 173/173 - 233s - loss: 0.6175 - accuracy: 0.7488 - val_loss: 0.5859 - val_accuracy: 0.7578 - lr: 1.0000e-05 - 233s/epoch - 1s/step
# Epoch 8/30
#
# Epoch 8: val_accuracy did not improve from 0.75775
# 173/173 - 219s - loss: 0.6081 - accuracy: 0.7435 - val_loss: 0.6180 - val_accuracy: 0.6860 - lr: 1.0000e-05 - 219s/epoch - 1s/step
# Epoch 9/30
#
# Epoch 9: val_accuracy did not improve from 0.75775
# 173/173 - 236s - loss: 0.5581 - accuracy: 0.7729 - val_loss: 0.6518 - val_accuracy: 0.6957 - lr: 1.0000e-05 - 236s/epoch - 1s/step
# Epoch 10/30
#
# Epoch 10: val_accuracy improved from 0.75775 to 0.76357, saving model to ../models/sparse_model_v2.h5
# 173/173 - 227s - loss: 0.5644 - accuracy: 0.7676 - val_loss: 0.5096 - val_accuracy: 0.7636 - lr: 1.0000e-05 - 227s/epoch - 1s/step
# Epoch 11/30
#
# Epoch 11: val_accuracy did not improve from 0.76357
# 173/173 - 220s - loss: 0.5298 - accuracy: 0.7865 - val_loss: 0.6448 - val_accuracy: 0.7132 - lr: 1.0000e-05 - 220s/epoch - 1s/step
# Epoch 12/30
#
# Epoch 12: val_accuracy did not improve from 0.76357
# 173/173 - 222s - loss: 0.5183 - accuracy: 0.7908 - val_loss: 0.6057 - val_accuracy: 0.7190 - lr: 1.0000e-05 - 222s/epoch - 1s/step
# Epoch 13/30
#
# Epoch 13: val_accuracy improved from 0.76357 to 0.78101, saving model to ../models/sparse_model_v2.h5
# 173/173 - 223s - loss: 0.5064 - accuracy: 0.7971 - val_loss: 0.5420 - val_accuracy: 0.7810 - lr: 1.0000e-05 - 223s/epoch - 1s/step
# Epoch 14/30
#
# Epoch 14: val_accuracy improved from 0.78101 to 0.81589, saving model to ../models/sparse_model_v2.h5
# 173/173 - 237s - loss: 0.4737 - accuracy: 0.8126 - val_loss: 0.4402 - val_accuracy: 0.8159 - lr: 2.0000e-06 - 237s/epoch - 1s/step
# Epoch 15/30
#
# Epoch 15: val_accuracy did not improve from 0.81589
# 173/173 - 215s - loss: 0.4807 - accuracy: 0.8155 - val_loss: 0.4822 - val_accuracy: 0.7965 - lr: 2.0000e-06 - 215s/epoch - 1s/step
# Epoch 16/30
#
# Epoch 16: val_accuracy improved from 0.81589 to 0.83140, saving model to ../models/sparse_model_v2.h5
# 173/173 - 226s - loss: 0.4809 - accuracy: 0.8068 - val_loss: 0.4372 - val_accuracy: 0.8314 - lr: 2.0000e-06 - 226s/epoch - 1s/step
# Epoch 17/30
#
# Epoch 17: val_accuracy did not improve from 0.83140
# 173/173 - 222s - loss: 0.4669 - accuracy: 0.8126 - val_loss: 0.5611 - val_accuracy: 0.7713 - lr: 2.0000e-06 - 222s/epoch - 1s/step
# Epoch 18/30
#
# Epoch 18: val_accuracy improved from 0.83140 to 0.83721, saving model to ../models/sparse_model_v2.h5
# 173/173 - 224s - loss: 0.4601 - accuracy: 0.8217 - val_loss: 0.4189 - val_accuracy: 0.8372 - lr: 2.0000e-06 - 224s/epoch - 1s/step
# Epoch 19/30
#
# Epoch 19: val_accuracy improved from 0.83721 to 0.85271, saving model to ../models/sparse_model_v2.h5
# 173/173 - 222s - loss: 0.4441 - accuracy: 0.8304 - val_loss: 0.3986 - val_accuracy: 0.8527 - lr: 2.0000e-06 - 222s/epoch - 1s/step
# Epoch 20/30
#
# Epoch 20: val_accuracy did not improve from 0.85271
# 173/173 - 225s - loss: 0.4543 - accuracy: 0.8198 - val_loss: 0.4174 - val_accuracy: 0.8353 - lr: 2.0000e-06 - 225s/epoch - 1s/step
# Epoch 21/30
#
# Epoch 21: val_accuracy did not improve from 0.85271
# 173/173 - 223s - loss: 0.4330 - accuracy: 0.8309 - val_loss: 0.4402 - val_accuracy: 0.8353 - lr: 2.0000e-06 - 223s/epoch - 1s/step
# Epoch 22/30
#
# Epoch 22: val_accuracy did not improve from 0.85271
# 173/173 - 225s - loss: 0.4517 - accuracy: 0.8280 - val_loss: 0.4619 - val_accuracy: 0.8178 - lr: 2.0000e-06 - 225s/epoch - 1s/step
# Epoch 23/30
#
# Epoch 23: val_accuracy did not improve from 0.85271
# 173/173 - 222s - loss: 0.4368 - accuracy: 0.8377 - val_loss: 0.4123 - val_accuracy: 0.8527 - lr: 1.0000e-06 - 222s/epoch - 1s/step
# Epoch 24/30
#
# Epoch 24: val_accuracy did not improve from 0.85271
# 173/173 - 221s - loss: 0.4435 - accuracy: 0.8271 - val_loss: 0.4019 - val_accuracy: 0.8469 - lr: 1.0000e-06 - 221s/epoch - 1s/step

# %% [markdown]
# **Result 2:** val_accuracy=85%.

# %%
pd.DataFrame(history_stage2.history).plot(figsize=(12, 4))
plt.show()

# %%
# Save model
# model.save(os.path.join(folder_models,f'sparse_model_v{version_model}.keras'))

# %% [markdown]
# In the next iteration, the model will be retrained with fine-tuning (last 20 layers).
