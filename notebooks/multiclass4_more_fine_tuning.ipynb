# %% [markdown]
# # Deep Learning (TensorFlow, Keras) with ResNet50: Image Multi-class Classifier (Part 4)
# In this project, a model is trained to perform multi-class classification for apple, banana and orange pictures. The pretrained model ResNet50 is used. This document is the fourth part of the whole training process.

# %% [markdown]
# ## Iteration 4: Model retraining, learning_rate=1e-4, data augmentation and fine-tuning (last 30 layers)

# %%
# (height, width, channels)
input_shape = (224, 224, 3)
batch_size = 12
learning_rate = 1e-4
path_dataset = '../fruits_dataset'
folder_apple = 'apple'
folder_banana = 'banana'
folder_orange = 'orange'
folder_models = '../models'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
# Out:
# 2025-10-25 20:41:54.282397: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-25 20:41:54.336852: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-25 20:41:54.337617: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-25 20:41:55.331783: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Data augmentation

# %%
def load_data(path, input_shape=input_shape, batch_size=batch_size, seed=123, validation_split=0.2):
    """Function to create 2 ImageDataGenerators to split dataset into train and validation datasets.
    Data augmentation is not implemented for the validation dataset."""
    height, width = input_shape[:2]
    datagen = ImageDataGenerator(rescale=1.0/255, zoom_range=0.1,
        horizontal_flip=True, vertical_flip=True,
        height_shift_range=0.1, width_shift_range=0.1,
        brightness_range=(0.8, 1.2), rotation_range=40,
        validation_split=validation_split
    )
    train_data = datagen.flow_from_directory(path,
        target_size=(height, width), batch_size=batch_size,
        class_mode='sparse', subset='training', seed=seed
    )
    val_datagen = ImageDataGenerator(rescale=1.0/255,
        validation_split=validation_split
    )
    val_data = val_datagen.flow_from_directory(path,
        target_size=(height, width), batch_size=batch_size,
        class_mode='sparse', subset='validation', seed=seed
    )
    return train_data, val_data

# Split training and validation datasets
train, val = load_data(path_dataset)

print(f"Classes found: {train.class_indices}")
print(f"Training images: {train.samples}")
print(f"Validation images: {val.samples}")
# Out:
# Found 2070 images belonging to 3 classes.
# Found 516 images belonging to 3 classes.
# Classes found: {'apple': 0, 'banana': 1, 'orange': 2}
# Training images: 2070
# Validation images: 516

# %%
# Obtain images and target
images, labels = next(train)

# Show 8 training images (batch_size=8)
figure, axes = plt.subplots(nrows=2,ncols=4, figsize=(8, 6))
for item in zip(axes.ravel(), images, labels):
    axes, image, target = item
    axes.imshow(image)
    axes.set_title(f'Target: {target:0.0f}')
    axes.set_xticks([])
    axes.set_yticks([])
plt.tight_layout()
plt.show()

# Image dimensions
print(images.shape)
# Out:
# (12, 224, 224, 3)

# %% [markdown]
# ### Model retraining (iteration 3)

# %%
def train_model(model, train_data, val_data, epochs, version_model):
    """Function to train the model and save the best one
    according to the validation accuracy."""
    file_name = os.path.join(folder_models,f'sparse_model_v{version_model}.h5')
    
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=0),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=0),
        ModelCheckpoint(file_name, monitor='val_accuracy', save_best_only=True, verbose=1)
    ]

    history = model.fit(train_data, validation_data=val_data,
              epochs=epochs, callbacks=callbacks, verbose=2)

    return model, history

# Load model v3
model_v4 = load_model(os.path.join(folder_models,'sparse_model_v3.h5'))
model_v4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)               262272
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 23850371 (90.98 MB)
# Trainable params: 9193987 (35.07 MB)
# Non-trainable params: 14656384 (55.91 MB)
# _________________________________________________________________

# %%
epochs = 30
version_model = 4
print(f"Parameters: batch_size = {batch_size}, learning_rate = {learning_rate}, epochs = {epochs}")
# Out:
# Parameters: batch_size = 12, learning_rate = 0.0001, epochs = 30

# %%
# Last 30 layers
for layer in model_v4.layers[0].layers[-30:]:
    layer.trainable = True

# Recompile
model_v4.compile(optimizer=Adam(learning_rate=learning_rate),
loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print(f"TensorFlow Version: {tf.__version__}")

# Ensure GPU is available
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0],True)
    print("GPU is available and memory growth is enabled.")
else:
    print("GPU not available, training will be on CPU.")
# Out:
# TensorFlow Version: 2.13.1
# GPU not available, training will be on CPU.

# %%
# Retrain the model
model_v4, history_stage4 = train_model(model_v4, train, val, epochs=epochs, version_model=version_model)
# Out:
# Epoch 1/30
# 2025-10-25 20:45:13.626086: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 38535168 exceeds 10% of free system memory.
# 2025-10-25 20:45:13.791182: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 38535168 exceeds 10% of free system memory.
# 2025-10-25 20:45:13.815001: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 39923712 exceeds 10% of free system memory.
# 2025-10-25 20:45:13.837725: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 38535168 exceeds 10% of free system memory.
# 2025-10-25 20:45:13.866285: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 38535168 exceeds 10% of free system memory.
# Epoch 1: val_accuracy improved from -inf to 0.58721, saving model to ../models/sparse_model_v4.h5
# /home/ant/TensorFlow-Keras-Multi-class-Classifier/env/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 173/173 - 395s - loss: 0.8411 - accuracy: 0.6261 - val_loss: 0.9508 - val_accuracy: 0.5872 - lr: 1.0000e-04 - 395s/epoch - 2s/step
# Epoch 2/30
#
# Epoch 2: val_accuracy improved from 0.58721 to 0.59690, saving model to ../models/sparse_model_v4.h5
# 173/173 - 450s - loss: 0.6277 - accuracy: 0.7198 - val_loss: 2.1556 - val_accuracy: 0.5969 - lr: 1.0000e-04 - 450s/epoch - 3s/step
# Epoch 3/30
#
# Epoch 3: val_accuracy did not improve from 0.59690
# 173/173 - 452s - loss: 0.5519 - accuracy: 0.7773 - val_loss: 1.0910 - val_accuracy: 0.5833 - lr: 1.0000e-04 - 452s/epoch - 3s/step
# Epoch 4/30
#
# Epoch 4: val_accuracy did not improve from 0.59690
# 173/173 - 435s - loss: 0.5203 - accuracy: 0.7802 - val_loss: 2.2079 - val_accuracy: 0.4516 - lr: 1.0000e-04 - 435s/epoch - 3s/step
# Epoch 5/30
#
# Epoch 5: val_accuracy improved from 0.59690 to 0.80814, saving model to ../models/sparse_model_v4.h5
# 173/173 - 466s - loss: 0.3791 - accuracy: 0.8493 - val_loss: 0.4734 - val_accuracy: 0.8081 - lr: 2.0000e-05 - 466s/epoch - 3s/step
# Epoch 6/30
#
# Epoch 6: val_accuracy did not improve from 0.80814
# 173/173 - 463s - loss: 0.3251 - accuracy: 0.8744 - val_loss: 1.0875 - val_accuracy: 0.7035 - lr: 2.0000e-05 - 463s/epoch - 3s/step
# Epoch 7/30
#
# Epoch 7: val_accuracy improved from 0.80814 to 0.88178, saving model to ../models/sparse_model_v4.h5
# 173/173 - 473s - loss: 0.3262 - accuracy: 0.8773 - val_loss: 0.2935 - val_accuracy: 0.8818 - lr: 2.0000e-05 - 473s/epoch - 3s/step
# Epoch 8/30
#
# Epoch 8: val_accuracy improved from 0.88178 to 0.91473, saving model to ../models/sparse_model_v4.h5
# 173/173 - 539s - loss: 0.3137 - accuracy: 0.8865 - val_loss: 0.2355 - val_accuracy: 0.9147 - lr: 2.0000e-05 - 539s/epoch - 3s/step
# Epoch 9/30
#
# Epoch 9: val_accuracy did not improve from 0.91473
# 173/173 - 508s - loss: 0.2994 - accuracy: 0.8831 - val_loss: 0.4623 - val_accuracy: 0.8256 - lr: 2.0000e-05 - 508s/epoch - 3s/step
# Epoch 10/30
#
# Epoch 10: val_accuracy did not improve from 0.91473
# 173/173 - 433s - loss: 0.2798 - accuracy: 0.8957 - val_loss: 1.9278 - val_accuracy: 0.4709 - lr: 2.0000e-05 - 433s/epoch - 3s/step
# Epoch 11/30
#
# Epoch 11: val_accuracy did not improve from 0.91473
# 173/173 - 305s - loss: 0.2502 - accuracy: 0.9000 - val_loss: 0.9238 - val_accuracy: 0.7112 - lr: 2.0000e-05 - 305s/epoch - 2s/step
# Epoch 12/30
#
# Epoch 12: val_accuracy improved from 0.91473 to 0.92636, saving model to ../models/sparse_model_v4.h5
# 173/173 - 293s - loss: 0.2663 - accuracy: 0.9068 - val_loss: 0.2055 - val_accuracy: 0.9264 - lr: 4.0000e-06 - 293s/epoch - 2s/step
# Epoch 13/30
#
# Epoch 13: val_accuracy did not improve from 0.92636
# 173/173 - 288s - loss: 0.2390 - accuracy: 0.9082 - val_loss: 0.2004 - val_accuracy: 0.9264 - lr: 4.0000e-06 - 288s/epoch - 2s/step
# Epoch 14/30
#
# Epoch 14: val_accuracy did not improve from 0.92636
# 173/173 - 282s - loss: 0.2205 - accuracy: 0.9188 - val_loss: 0.2186 - val_accuracy: 0.9225 - lr: 4.0000e-06 - 282s/epoch - 2s/step
# Epoch 15/30
#
# Epoch 15: val_accuracy did not improve from 0.92636
# 173/173 - 275s - loss: 0.2216 - accuracy: 0.9242 - val_loss: 0.2250 - val_accuracy: 0.9147 - lr: 4.0000e-06 - 275s/epoch - 2s/step
# Epoch 16/30
#
# Epoch 16: val_accuracy improved from 0.92636 to 0.93605, saving model to ../models/sparse_model_v4.h5
# 173/173 - 292s - loss: 0.2118 - accuracy: 0.9198 - val_loss: 0.1860 - val_accuracy: 0.9360 - lr: 4.0000e-06 - 292s/epoch - 2s/step
# Epoch 17/30
#
# Epoch 17: val_accuracy did not improve from 0.93605
# 173/173 - 292s - loss: 0.2103 - accuracy: 0.9256 - val_loss: 0.1777 - val_accuracy: 0.9302 - lr: 4.0000e-06 - 292s/epoch - 2s/step
# Epoch 18/30
#
# Epoch 18: val_accuracy did not improve from 0.93605
# 173/173 - 285s - loss: 0.2079 - accuracy: 0.9213 - val_loss: 0.1782 - val_accuracy: 0.9341 - lr: 4.0000e-06 - 285s/epoch - 2s/step
# Epoch 19/30
#
# Epoch 19: val_accuracy improved from 0.93605 to 0.94961, saving model to ../models/sparse_model_v4.h5
# 173/173 - 290s - loss: 0.1862 - accuracy: 0.9295 - val_loss: 0.1554 - val_accuracy: 0.9496 - lr: 4.0000e-06 - 290s/epoch - 2s/step
# Epoch 20/30
#
# Epoch 20: val_accuracy did not improve from 0.94961
# 173/173 - 281s - loss: 0.1938 - accuracy: 0.9256 - val_loss: 0.1567 - val_accuracy: 0.9477 - lr: 4.0000e-06 - 281s/epoch - 2s/step
# Epoch 21/30
#
# Epoch 21: val_accuracy did not improve from 0.94961
# 173/173 - 278s - loss: 0.1804 - accuracy: 0.9290 - val_loss: 0.1698 - val_accuracy: 0.9264 - lr: 4.0000e-06 - 278s/epoch - 2s/step
# Epoch 22/30
#
# Epoch 22: val_accuracy did not improve from 0.94961
# 173/173 - 293s - loss: 0.1631 - accuracy: 0.9367 - val_loss: 0.1556 - val_accuracy: 0.9438 - lr: 4.0000e-06 - 293s/epoch - 2s/step
# Epoch 23/30
#
# Epoch 23: val_accuracy did not improve from 0.94961
# 173/173 - 266s - loss: 0.1847 - accuracy: 0.9338 - val_loss: 0.1487 - val_accuracy: 0.9457 - lr: 1.0000e-06 - 266s/epoch - 2s/step
# Epoch 24/30
#
# Epoch 24: val_accuracy did not improve from 0.94961
# 173/173 - 287s - loss: 0.1730 - accuracy: 0.9319 - val_loss: 0.1664 - val_accuracy: 0.9302 - lr: 1.0000e-06 - 287s/epoch - 2s/step
# Epoch 25/30
#
# Epoch 25: val_accuracy improved from 0.94961 to 0.95155, saving model to ../models/sparse_model_v4.h5
# 173/173 - 282s - loss: 0.1808 - accuracy: 0.9290 - val_loss: 0.1521 - val_accuracy: 0.9516 - lr: 1.0000e-06 - 282s/epoch - 2s/step
# Epoch 26/30
#
# Epoch 26: val_accuracy did not improve from 0.95155
# 173/173 - 283s - loss: 0.1699 - accuracy: 0.9425 - val_loss: 0.1537 - val_accuracy: 0.9457 - lr: 1.0000e-06 - 283s/epoch - 2s/step
# Epoch 27/30
#
# Epoch 27: val_accuracy did not improve from 0.95155
# 173/173 - 282s - loss: 0.1969 - accuracy: 0.9251 - val_loss: 0.1472 - val_accuracy: 0.9438 - lr: 1.0000e-06 - 282s/epoch - 2s/step
# Epoch 28/30
#
# Epoch 28: val_accuracy did not improve from 0.95155
# 173/173 - 282s - loss: 0.1739 - accuracy: 0.9338 - val_loss: 0.1421 - val_accuracy: 0.9457 - lr: 1.0000e-06 - 282s/epoch - 2s/step
# Epoch 29/30
#
# Epoch 29: val_accuracy did not improve from 0.95155
# 173/173 - 279s - loss: 0.1615 - accuracy: 0.9464 - val_loss: 0.1632 - val_accuracy: 0.9399 - lr: 1.0000e-06 - 279s/epoch - 2s/step
# Epoch 30/30
#
# Epoch 30: val_accuracy did not improve from 0.95155
# 173/173 - 277s - loss: 0.1625 - accuracy: 0.9382 - val_loss: 0.1460 - val_accuracy: 0.9477 - lr: 1.0000e-06 - 277s/epoch - 2s/step

# %% [markdown]
# **Result 4:** val_accuracy=95%.

# %%
pd.DataFrame(history_stage4.history).plot(figsize=(12, 4))
plt.show()

# %%
# Save model
# model.save(os.path.join(folder_models,f'sparse_model_v{version_model}.keras'))
